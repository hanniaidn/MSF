# %% [markdown]
# Lyapunov Stability

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#definimos el dominio D
x1=np.linspace(-3,3,100)
x2=np.linspace(-2,2,100)
a=0.25

#para poder usar la malla de D 
X1,X2=np.meshgrid(x1,x2)

V=lambda x1, x2 : x1**2 + x2**2 #la funcion definida

# %%
#graficar tipo surface 
fig, ax= plt.subplots(subplot_kw={"projection": "3d"}, figsize=(10,8))
surf=ax.plot_surface(X1,X2,V(X1,X2), cmap='viridis', linewidth=0,antialiased = False)
#para obtener las curvas de nivel 
ax.contour(X1,X2, V(x1, X2), cmap='viridis',offset = -1)

# %%
#ahora definimos el campo vectorial 
u=-2*x1
v=-2*x2

# Calcular los valores de V para cada punto en la malla
#Z = V(X1, X2) 

#Vx1, Vx2 = np.gradient(Z)
#para graficarlo con flechas
#ax.quiver(X1, X2, Z, Vx1, Vx2, np.zeros_like(Z), length=0.3, color='black')

# #Usamos quiver para graficar un campo vectorial en 2D.
plt.figure()
plt.quiver(X1, X2, V(X1, X2), X1, X2)

# Generamos la tercer componente del campo, en este caso 0
w = np.zeros_like(X1)

# Graficamos el campo vectorial en 3D
ax.quiver(X1, X2, V(X1, X2), u, v, w, length=0.2, color='r')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 20
#      17 w = np.zeros_like(X1)
#      19 # Graficamos el campo vectorial en 3D
# ---> 20 ax.quiver(X1, X2, V(X1, X2), u, v, w, length=0.2, color='r')
#      23 plt.show()
#
# File ~/Desktop/Modelado1/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/Desktop/Modelado1/.venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5379, in Axes.quiver(self, *args, **kwargs)
#    5377 # Make sure units are handled for x and y values
#    5378 args = self._quiver_units(args, kwargs)
# -> 5379 q = mquiver.Quiver(self, *args, **kwargs)
#    5380 self.add_collection(q, autolim=True)
#    5381 self._request_autoscale_view()
#
# File ~/Desktop/Modelado1/.venv/lib/python3.12/site-packages/matplotlib/quiver.py:475, in Quiver.__init__(self, ax, scale, headwidth, headlength, headaxislength, minshaft, minlength, units, scale_units, angles, width, color, pivot, *args, **kwargs)
#     468 """
#     469 The constructor takes one required argument, an Axes
#     470 instance, followed by the args and kwargs described
#     471 by the following pyplot interface documentation:
#     472 %s
#     473 """
#     474 self._axes = ax  # The attr actually set by the Artist.axes property.
# --> 475 X, Y, U, V, C = _parse_args(*args, caller_name='quiver')
#     476 self.X = X
#     477 self.Y = Y
#
# File ~/Desktop/Modelado1/.venv/lib/python3.12/site-packages/matplotlib/quiver.py:418, in _parse_args(caller_name, *args)
#     416     X, Y, U, V, C = np.atleast_1d(*args)
#     417 else:
# --> 418     raise _api.nargs_error(caller_name, takes="from 2 to 5", given=nargs)
#     420 nr, nc = (1, U.shape[0]) if U.ndim == 1 else U.shape
#     422 if X is not None:
#
# TypeError: quiver() takes from 2 to 5 positional arguments but 6 were given

# %%
# Crear la figura solamente las curvas de nivel 
fig, ax = plt.subplots()

# Dibujar las curvas de nivel
contour = ax.contour(X1, X2, V(X1,X2), levels=20, cmap='viridis')

# Añadir etiquetas a las curvas de nivel
ax.clabel(contour, inline=True, fontsize=8)

# Mostrar la gráfica
plt.show()

# %%
# Calcular el gradiente (campo vectorial)
Vx1, Vx2 = np.gradient(Z)

# Crear la figura y los ejes 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
#ax.plot_surface(X1, X2, Z, cmap='viridis', alpha=0.7)

# Agregar el campo vectorial al plano XY con flechas
ax.quiver(X1, X2, Z, Vx1, Vx2, np.zeros_like(Z), length=0.3, color='black')

# Mostrar la gráfica
plt.show()
